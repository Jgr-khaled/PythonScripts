# %% [markdown]
# A basic Python code that analyzes a presidential speech and extracts useful information about politics or the president.
# This code assumes that you have a presidential speech in text format.

# %%
#Step 1: Load the speech

with open('bush.txt', 'r') as file:
    speech = file.read()

# %%
#Step 2: Tokenize the speech

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# Tokenize the speech into words
words = word_tokenize(speech)

# Tokenize the speech into sentences
sentences = sent_tokenize(speech)
print(words)
# Out:
# ['On', 'my', 'orders', ',', 'the', 'United', 'States', 'military', 'has', 'begun', 'strikes', 'against', 'al-Qaida', 'terrorist', 'training', 'camps', 'and', 'military', 'installations', 'of', 'the', 'Taliban', 'regime', 'in', 'Afghanistan', '.', 'These', 'carefully', 'targeted', 'actions', 'are', 'designed', 'to', 'disrupt', 'the', 'use', 'of', 'Afghanistan', 'as', 'a', 'terrorist', 'base', 'of', 'operations', 'and', 'to', 'attack', 'the', 'military', 'capability', 'of', 'the', 'Taliban', 'regime', '.', 'We', 'are', 'joined', 'in', 'this', 'operation', 'by', 'our', 'staunch', 'friend', ',', 'Great', 'Britain', '.', 'Other', 'close', 'friends', ',', 'including', 'Canada', ',', 'Australia', ',', 'Germany', 'and', 'France', ',', 'have', 'pledged', 'forces', 'as', 'the', 'operation', 'unfolds', '.', 'More', 'than', '40', 'countries', 'in', 'the', 'Middle', 'East', ',', 'Africa', ',', 'Europe', 'and', 'across', 'Asia', 'have', 'granted', 'air', 'transit', 'or', 'landing', 'rights', '.', 'Many', 'more', 'have', 'shared', 'intelligence', '.', 'We', 'are', 'supported', 'by', 'the', 'collective', 'will', 'of', 'the', 'world', '.', 'More', 'than', 'two', 'weeks', 'ago', ',', 'I', 'gave', 'Taliban', 'leaders', 'a', 'series', 'of', 'clear', 'and', 'specific', 'demands', ':', 'Close', 'terrorist', 'training', 'camps', '.', 'Hand', 'over', 'leaders', 'of', 'the', 'al-Qaida', 'network', ',', 'and', 'return', 'all', 'foreign', 'nationals', ',', 'including', 'American', 'citizens', 'unjustly', 'detained', 'in', 'your', 'country', '.', 'None', 'of', 'these', 'demands', 'were', 'met', '.', 'And', 'now', ',', 'the', 'Taliban', 'will', 'pay', 'a', 'price', '.', 'By', 'destroying', 'camps', 'and', 'disrupting', 'communications', ',', 'we', 'will', 'make', 'it', 'more', 'difficult', 'for', 'the', 'terror', 'network', 'to', 'train', 'new', 'recruits', 'and', 'coordinate', 'their', 'evil', 'plans', '.', 'Initially', ',', 'the', 'terrorists', 'may', 'burrow', 'deeper', 'into', 'caves', 'and', 'other', 'entrenched', 'hiding', 'places', '.', 'Our', 'military', 'action', 'is', 'also', 'designed', 'to', 'clear', 'the', 'way', 'for', 'sustained', ',', 'comprehensive', 'and', 'relentless', 'operations', 'to', 'drive', 'them', 'out', 'and', 'bring', 'them', 'to', 'justice', '.', 'At', 'the', 'same', 'time', ',', 'the', 'oppressed', 'people', 'of', 'Afghanistan', 'will', 'know', 'the', 'generosity', 'of', 'America', 'and', 'our', 'allies', '.', 'As', 'we', 'strike', 'military', 'targets', ',', 'we', 'will', 'also', 'drop', 'food', ',', 'medicine', 'and', 'supplies', 'to', 'the', 'starving', 'and', 'suffering', 'men', 'and', 'women', 'and', 'children', 'of', 'Afghanistan', '.', 'The', 'United', 'States', 'of', 'America', 'is', 'a', 'friend', 'to', 'the', 'Afghan', 'people', ',', 'and', 'we', 'are', 'the', 'friends', 'of', 'almost', 'a', 'billion', 'worldwide', 'who', 'practice', 'the', 'Islamic', 'faith', '.', 'The', 'United', 'States', 'of', 'America', 'is', 'an', 'enemy', 'of', 'those', 'who', 'aid', 'terrorists', 'and', 'of', 'the', 'barbaric', 'criminals', 'who', 'profane', 'a', 'great', 'religion', 'by', 'committing', 'murder', 'in', 'its', 'name', '.', 'This', 'military', 'action', 'is', 'a', 'part', 'of', 'our', 'campaign', 'against', 'terrorism', ',', 'another', 'front', 'in', 'a', 'war', 'that', 'has', 'already', 'been', 'joined', 'through', 'diplomacy', ',', 'intelligence', ',', 'the', 'freezing', 'of', 'financial', 'assets', 'and', 'the', 'arrests', 'of', 'known', 'terrorists', 'by', 'law', 'enforcement', 'agents', 'in', '38', 'countries', '.', 'Given', 'the', 'nature', 'and', 'reach', 'of', 'our', 'enemies', ',', 'we', 'will', 'win', 'this', 'conflict', 'by', 'the', 'patient', 'accumulation', 'of', 'successes', ',', 'by', 'meeting', 'a', 'series', 'of', 'challenges', 'with', 'determination', 'and', 'will', 'and', 'purpose', '.', 'Today', 'we', 'focus', 'on', 'Afghanistan', ',', 'but', 'the', 'battle', 'is', 'broader', '.', 'Every', 'nation', 'has', ...

# %%
#

from nltk import ne_chunk, pos_tag

# Extract named entities
entities = ne_chunk(pos_tag(words), binary=False)
print(entities)
# Out:
# (S
#   On/IN
#   my/PRP$
#   orders/NNS
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   military/JJ
#   has/VBZ
#   begun/VBN
#   strikes/NNS
#   against/IN
#   al-Qaida/JJ
#   terrorist/JJ
#   training/NN
#   camps/NNS
#   and/CC
#   military/JJ
#   installations/NNS
#   of/IN
#   the/DT
#   (GPE Taliban/NNP)
#   regime/NN
#   in/IN
#   (GPE Afghanistan/NNP)
#   ./.
#   These/DT
#   carefully/RB
#   targeted/VBN
#   actions/NNS
#   are/VBP
#   designed/VBN
#   to/TO
#   disrupt/VB
#   the/DT
#   use/NN
#   of/IN
#   (GPE Afghanistan/NNP)
#   as/IN
#   a/DT
#   terrorist/JJ
#   base/NN
#   of/IN
#   operations/NNS
#   and/CC
#   to/TO
#   attack/VB
#   the/DT
#   military/JJ
#   capability/NN
#   of/IN
#   the/DT
#   (GPE Taliban/NNP)
#   regime/NN
#   ./.
#   We/PRP
#   are/VBP
#   joined/VBN
#   in/IN
#   this/DT
#   operation/NN
#   by/IN
#   our/PRP$
#   staunch/NN
#   friend/NN
#   ,/,
#   (PERSON Great/NNP Britain/NNP)
#   ./.
#   Other/JJ
#   close/JJ
#   friends/NNS
#   ,/,
#   including/VBG
#   (GPE Canada/NNP)
#   ,/,
#   (GPE Australia/NNP)
#   ,/,
#   (GPE Germany/NNP)
#   and/CC
#   (GPE France/NNP)
#   ,/,
#   have/VBP
#   pledged/VBN
#   forces/NNS
#   as/IN
#   the/DT
#   operation/NN
#   unfolds/VBZ
#   ./.
#   More/JJR
#   than/IN
#   40/CD
#   countries/NNS
#   in/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   ,/,
#   (GPE Africa/NNP)
#   ,/,
#   (GPE Europe/NNP)
#   and/CC
#   across/IN
#   (GPE Asia/NNP)
#   have/VBP
#   granted/VBN
#   air/NN
#   transit/NN
#   or/CC
#   landing/NN
#   rights/NNS
#   ./.
#   Many/NNP
#   more/JJR
#   have/VBP
#   shared/VBN
#   intelligence/NN
#   ./.
#   We/PRP
#   are/VBP
#   supported/VBN
#   by/IN
#   the/DT
#   collective/NN
#   will/MD
#   of/IN
#   the/DT
#   world/NN
#   ./.
#   More/JJR
#   than/IN
#   two/CD
#   weeks/NNS
#   ago/RB
#   ,/,
#   I/PRP
#   gave/VBD
#   (PERSON Taliban/NNP)
#   leaders/NNS
#   a/DT
#   series/NN
#   of/IN
#   clear/JJ
#   and/CC
#   specific/JJ
#   demands/NNS
#   :/:
#   Close/NNP
#   terrorist/JJ
#   training/NN
#   camps/NNS
#   ./.
#   (PERSON Hand/NNP)
#   over/IN
#   leaders/NNS
#   of/IN
#   the/DT
#   al-Qaida/JJ
#   network/NN
#   ,/,
#   and/CC
#   return/VB
#   all/DT
#   foreign/JJ
#   nationals/NNS
#   ,/,
#   including/VBG
#   (GPE American/JJ)
#   citizens/NNS
#   unjustly/RB
#   detained/VBN
#   in/IN
#   your/PRP$
#   country/NN
#   ./.
#   None/NN
#   of/IN
#   these/DT
#   demands/NNS
#   were/VBD
#   met/VBN
#   ./.
#   And/CC
#   now/RB
#   ,/,
#   the/DT
#   (ORGANIZATION Taliban/NNP)
#   will/MD
#   pay/VB
#   a/DT
#   price/NN
#   ./.
#   By/IN
#   destroying/VBG
#   camps/NNS
#   and/CC
#   disrupting/VBG
#   communications/NNS
#   ,/,
#   we/PRP
#   will/MD
#   make/VB
#   it/PRP
#   more/RBR
#   difficult/JJ
#   for/IN
#   the/DT
#   terror/NN
#   network/NN
#   to/TO
#   train/VB
#   new/JJ
#   recruits/NNS
#   and/CC
#   coordinate/VB
#   their/PRP$
#   evil/JJ
#   plans/NNS
#   ./.
#   Initially/RB
#   ,/,
#   the/DT
#   terrorists/NNS
#   may/MD
#   burrow/VB
#   deeper/JJR
#   into/IN
#   caves/NNS
#   and/CC
#   other/JJ
#   entrenched/VBD
#   hiding/VBG
#   places/NNS
#   ./.
#   Our/PRP$
#   military/JJ
#   action/NN
#   is/VBZ
#   also/RB
#   designed/VBN
#   to/TO
#   clear/VB
#   the/DT
#   way/NN
#   for/IN
#   sustained/VBN
#   ,/,
#   comprehensive/JJ
#   and/CC
#   relentless/JJ
#   operations/NNS
#   to/TO
#   drive/VB
#   them/PRP
#   out/RP
#   and/CC
#   bring/VB
#   them/PRP
#   to/TO
#   justice/VB
#   ./.
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   the/DT
#   oppressed/JJ
#   people/NNS
#   of/IN
#   (GPE Afghanistan/NNP)
#   will/MD
#   know/VB
#   the/DT
#   generosity/NN
#   of/IN
#   (GPE America/NNP)
#   and/CC
#   our/PRP$
#   allies/NNS
#   ./.
#   As/IN
#   we/PRP
#   strike/VBP
#   military/JJ
#   targets/NNS
#   ,/,
#   we/PRP
#   will/MD
#   also/RB
#   drop/VB
#   food/NN
#   ,/,
#   medicine/NN
#   and/CC
#   supplies/NNS
#   to/TO
#   the/DT
#   starving/NN
#   and/CC
#   suffering/VBG
#   men/NNS
#   and/CC
#   women/NNS
#   and/CC
#   children/NNS
#   of/IN
#   (GPE Afghanistan/NNP)
#   ./.
#   The/DT
#   (GPE United/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   is/VBZ
#   a/DT
#   friend/NN
#   to/TO
#   the/DT
#   (ORGANIZATION Afghan/NNP)
#   people/NNS
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   the/DT
#   friends/NNS
#   of/IN
#   almost/RB
#   a/DT
#   billion/CD
#   worldwide/NN
#   who/WP
#   practice/NN
#   the/DT
#   (ORGANIZATION Islamic/NNP)
#   faith/NN
#   ./.
#   The/DT
#   (GPE United/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   is/VBZ
#   an/DT
#   enemy/NN
#   of/IN
#   those/DT
#   who/WP
#   aid/VBP
#   terrorists/NNS
#   and/CC
#   of/IN
#   the/DT
#   barbaric/JJ
#   criminals/NNS
#   who/WP
#   profane/VBP
#   a/DT
#   great/JJ
#   religion/NN
#   by/IN
#   committing/VBG
#   murder/NN
#   in/IN
#   its/PRP$
#   name/NN
#   ./.
#   This/DT
#   military/JJ
#   action/NN
#   is/VBZ
#   a/DT
#   part/NN
#   of/IN
#   our/PRP$
#   campaign/NN
#   against/IN
#   terrorism/NN
#   ,/,
#   another/DT
#   front/NN
#   in/IN
#   a/DT
#   war/NN
#   that/WDT
#   has/VBZ
#   already/RB
#   been/VBN
#   joined/VBN
#   through/IN
#   diplomacy/NN
#   ,/,
#   intelligence/NN
#   ,/,
#   the/DT
#   freezing/NN
#   of/IN
#   financial/JJ
#   assets/NNS
#   and/CC
#   the/DT
#   arrests/NNS
#   of/IN
#   known/VBN
#   terrorists/NNS
#   by/IN
#   law/NN
#   enforcement/NN
#   agents/NNS
#   in/IN
#   38/CD
#   countries/NNS
#   ./.
#   Given/VB
#   the/DT
#   nature/NN
#   and/CC
#   reach/NN
#   of/IN
#   our/PRP$
#   enemies/NNS
#   ,/,
#   we/PRP
#   will/MD
#   win/VB
#   this/DT
#   conflict/NN
#   by/IN
#   the/DT
#   patient/JJ
#   accumulation/NN
#   of/IN
#   successes/NNS
#   ,/,
#   by/IN
#   meeting/VBG
#   a/DT
#   series/NN
#   of/IN
#   challenges/NNS
#   with/IN
#   determination/NN
#   and/CC
#   will/MD
#   and/CC
#   purpose/VB
#   ./.
#   Today/NN
#   we/PRP
#   focus/VBP
#   on/IN
#   (GPE Afghanistan/NNP)
#   ,/,
#   but/CC
#   the/DT
#   battle/NN
#   is/VBZ
#   broader/JJR
#   ./.
#   Every/DT
#   nation/NN
#   has/VBZ
#   a/DT
#   choice/NN
#   to/TO
#   make/VB
#   ./.
#   In/IN
#   this/DT
#   conflict/NN
#   ,/,
#   there/EX
#   is/VBZ
#   no/DT
#   neutral/JJ
#   ground/NN
#   ./.
#   If/IN
#   any/DT
#   government/NN
#   sponsors/NNS
#   the/DT
#   outlaws/NNS
#   and/CC
#   killers/NNS
#   of/IN
#   innocents/NNS
#   ,/,
#   they/PRP
#   have/VBP
#   become/VBN
#   outlaws/NNS
#   and/CC
#   murderers/NNS
#   themselves/PRP
#   ./.
#   And/CC
#   they/PRP
#   will/MD
#   take/VB
#   that/DT
#   lonely/JJ
#   path/NN
#   at/IN
#   their/PRP$
#   own/JJ
#   peril/NN
#   ./.
#   I/PRP
#   'm/VBP
#   speaking/VBG
#   to/TO
#   you/PRP
#   today/NN
#   from/IN
#   the/DT
#   (ORGANIZATION Treaty/NNP Room/NNP)
#   of/IN
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   ,/,
#   a/DT
#   place/NN
#   where/WRB
#   (GPE American/JJ)
#   presidents/NNS
#   have/VBP
#   worked/VBN
#   for/IN
#   peace/NN
#   ./.
#   We/PRP
#   're/VBP
#   a/DT
#   peaceful/JJ
#   nation/NN
#   ./.
#   Yet/RB
#   ,/,
#   as/IN
#   we/PRP
#   have/VBP
#   learned/VBN
#   ,/,
#   so/IN
#   suddenly/RB
#   and/CC
#   so/RB
#   tragically/RB
#   ,/,
#   there/EX
#   can/MD
#   be/VB
#   no/DT
#   peace/NN
#   in/IN
#   a/DT
#   world/NN
#   of/IN
#   sudden/JJ
#   terror/NN
#   ./.
#   In/IN
#   the/DT
#   face/NN
#   of/IN
#   today/NN
#   's/POS
#   new/JJ
#   threat/NN
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   pursue/VB
#   peace/NN
#   is/VBZ
#   to/TO
#   pursue/VB
#   those/DT
#   who/WP
#   threaten/VBP
#   it/PRP
#   ./.
#   We/PRP
#   did/VBD
#   not/RB
#   ask/VB
#   for/IN
#   this/DT
#   mission/NN
#   ,/,
#   but/CC
#   we/PRP
#   will/MD
#   fulfill/VB
#   it/PRP
#   ./.
#   The/DT
#   name/NN
#   of/IN
#   today/NN
#   's/POS
#   military/JJ
#   operation/NN
#   is/VBZ
#   Enduring/VBG
#   (PERSON Freedom/NNP)
#   ./.
#   We/PRP
#   defend/VBP
#   not/RB
#   only/RB
#   our/PRP$
#   precious/JJ
#   freedoms/NNS
#   ,/,
#   but/CC
#   also/RB
#   the/DT
#   freedom/NN
#   of/IN
#   people/NNS
#   everywhere/RB
#   to/TO
#   live/VB
#   and/CC
#   raise/VB
#   their/PRP$
#   children/NNS
#   free/VBP
#   from/IN
#   fear/NN
#   ./.
#   I/PRP
#   know/VBP
#   many/JJ
#   Americans/NNPS
#   feel/VBP
#   fear/RB
#   today/NN
#   ./.
#   And/CC
#   our/PRP$
#   government/NN
#   is/VBZ
#   taking/VBG
#   strong/JJ
#   precautions/NNS
#   ./.
#   All/DT
#   law/NN
#   enforcement/NN
#   and/CC
#   intelligence/NN
#   agencies/NNS
#   are/VBP
#   working/VBG
#   aggressively/RB
#   around/IN
#   (GPE America/NNP)
#   ,/,
#   around/IN
#   the/DT
#   world/NN
#   and/CC
#   around/IN
#   the/DT
#   clock/NN
#   ./.
#   At/IN
#   my/PRP$
#   request/NN
#   ,/,
#   many/JJ
#   governors/NNS
#   have/VBP
#   activated/VBN
#   the/DT
#   (ORGANIZATION National/NNP Guard/NNP)
#   to/TO
#   strengthen/VB
#   airport/JJ
#   security/NN
#   ./.
#   We/PRP
#   have/VBP
#   called/VBN
#   up/RP
#   reserves/NNS
#   to/TO
#   reinforce/VB
#   our/PRP$
#   military/JJ
#   capability/NN
#   and/CC
#   strengthen/VB
#   the/DT
#   protection/NN
#   of/IN
#   our/PRP$
#   homeland/NN
#   ./.
#   In/IN
#   the/DT
#   months/NNS
#   ahead/RB
#   ,/,
#   our/PRP$
#   patience/NN
#   will/MD
#   be/VB
#   one/CD
#   of/IN
#   our/PRP$
#   strengths/NNS
#   -/:
#   patience/NN
#   with/IN
#   the/DT
#   long/JJ
#   waits/NNS
#   that/WDT
#   will/MD
#   result/VB
#   from/IN
#   tighter/JJR
#   security/NN
#   ,/,
#   patience/NN
#   and/CC
#   understanding/NN
#   that/IN
#   it/PRP
#   will/MD
#   take/VB
#   time/NN
#   to/TO
#   achieve/VB
#   our/PRP$
#   goals/NNS
#   ,/,
#   patience/NN
#   in/IN
#   all/PDT
#   the/DT
#   sacrifices/NNS
#   that/WDT
#   may/MD
#   come/VB
#   ./.
#   Today/NN
#   ,/,
#   those/DT
#   sacrifices/NNS
#   are/VBP
#   being/VBG
#   made/VBN
#   by/IN
#   members/NNS
#   of/IN
#   our/PRP$
#   armed/JJ
#   forces/NNS
#   who/WP
#   now/RB
#   defend/VBP
#   us/PRP
#   so/RB
#   far/RB
#   from/IN
#   home/NN
#   ,/,
#   and/CC
#   by/IN
#   their/PRP$
#   proud/NN
#   and/CC
#   worried/JJ
#   families/NNS
#   ./.
#   A/DT
#   commander/NN
#   in/IN
#   chief/NN
#   sends/NNS
#   (GPE America/NNP)
#   's/POS
#   sons/NNS
#   and/CC
#   daughters/NNS
#   into/IN
#   a/DT
#   battle/NN
#   in/IN
#   a/DT
#   foreign/JJ
#   land/NN
#   only/RB
#   after/IN
#   the/DT
#   greatest/JJS
#   care/NN
#   and/CC
#   a/DT
#   lot/NN
#   of/IN
#   prayer/NN
#   ./.
#   We/PRP
#   ask/VBP
#   a/DT
#   lot/NN
#   of/IN
#   those/DT
#   who/WP
#   wear/VBP
#   our/PRP$
#   uniform/NN
#   ./.
#   We/PRP
#   ask/VBP
#   them/PRP
#   to/TO
#   leave/VB
#   their/PRP$
#   loved/JJ
#   ones/NNS
#   ,/,
#   to/TO
#   travel/VB
#   great/JJ
#   distances/NNS
#   ,/,
#   to/TO
#   risk/VB
#   injury/NN
#   ,/,
#   even/RB
#   to/TO
#   be/VB
#   prepared/VBN
#   to/TO
#   make/VB
#   the/DT
#   ultimate/JJ
#   sacrifice/NN
#   of/IN
#   their/PRP$
#   lives/NNS
#   ./.
#   They/PRP
#   are/VBP
#   dedicated/VBN
#   ./.
#   They/PRP
#   are/VBP
#   honorable/JJ
#   ./.
#   They/PRP
#   represent/VBP
#   the/DT
#   best/JJS
#   of/IN
#   our/PRP$
#   country/NN
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   ./.
#   To/TO
#   all/PDT
#   the/DT
#   men/NNS
#   and/CC
#   women/NNS
#   in/IN
#   our/PRP$
#   military/JJ
#   ,/,
#   every/DT
#   sailor/NN
#   ,/,
#   every/DT
#   soldier/NN
#   ,/,
#   every/DT
#   airman/NN
#   ,/,
#   every/DT
#   Coast/NNP
#   Guardsman/NNP
#   ,/,
#   every/DT
#   (PERSON Marine/NNP)
#   ,/,
#   I/PRP
#   say/VBP
#   this/DT
#   :/:
#   Your/PRP$
#   mission/NN
#   is/VBZ
#   defined/VBN
#   ./.
#   Your/PRP$
#   objectives/NNS
#   are/VBP
#   clear/JJ
#   ./.
#   Your/PRP$
#   goal/NN
#   is/VBZ
#   just/RB
#   ./.
#   You/PRP
#   have/VBP
#   my/PRP$
#   full/JJ
#   confidence/NN
#   ,/,
#   and/CC
#   you/PRP
#   will/MD
#   have/VB
#   every/DT
#   tool/NN
#   you/PRP
#   need/VBP
#   to/TO
#   carry/VB
#   out/RP
#   your/PRP$
#   duty/NN
#   ./.
#   I/PRP
#   recently/RB
#   received/VBD
#   a/DT
#   touching/JJ
#   letter/NN
#   that/WDT
#   says/VBZ
#   a/DT
#   lot/NN
#   about/IN
#   the/DT
#   state/NN
#   of/IN
#   (GPE America/NNP)
#   in/IN
#   these/DT
#   difficult/JJ
#   times/NNS
#   ,/,
#   a/DT
#   letter/NN
#   from/IN
#   a/DT
#   fourth/JJ
#   grade/NN
#   girl/NN
#   with/IN
#   a/DT
#   father/NN
#   in/IN
#   the/DT
#   military/NN
#   ./.
#   ''/''
#   As/RB
#   much/JJ
#   as/IN
#   I/PRP
#   do/VBP
#   n't/RB
#   want/VB
#   my/PRP$
#   dad/NN
#   to/TO
#   fight/VB
#   ,/,
#   ''/''
#   she/PRP
#   wrote/VBD
#   ,/,
#   ``/``
#   I/PRP
#   'm/VBP
#   willing/JJ
#   to/TO
#   give/VB
#   him/PRP
#   to/TO
#   you/PRP
#   ./.
#   ''/''
#   This/DT
#   is/VBZ
#   a/DT
#   precious/JJ
#   gift/NN
#   ./.
#   The/DT
#   greatest/JJS
#   she/PRP
#   could/MD
#   give/VB
#   ./.
#   This/DT
#   young/JJ
#   girl/NN
#   knows/VBZ
#   what/WP
#   (GPE America/NNP)
#   is/VBZ
#   all/DT
#   about/IN
#   ./.
#   Since/IN
#   September/NNP
#   11/CD
#   ,/,
#   an/DT
#   entire/JJ
#   generation/NN
#   of/IN
#   young/JJ
#   Americans/NNPS
#   has/VBZ
#   gained/VBN
#   new/JJ
#   understanding/NN
#   of/IN
#   the/DT
#   value/NN
#   of/IN
#   freedom/NN
#   and/CC
#   its/PRP$
#   cost/NN
#   and/CC
#   duty/NN
#   and/CC
#   its/PRP$
#   sacrifice/NN
#   ./.
#   The/DT
#   battle/NN
#   is/VBZ
#   now/RB
#   joined/VBN
#   on/IN
#   many/JJ
#   fronts/NNS
#   ./.
#   We/PRP
#   will/MD
#   not/RB
#   waver/VB
#   ,/,
#   we/PRP
#   will/MD
#   not/RB
#   tire/VB
#   ,/,
#   we/PRP
#   will/MD
#   not/RB
#   falter/VB
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   not/RB
#   fail/VB
#   ./.
#   (PERSON Peace/NNP)
#   and/CC
#   freedom/NN
#   will/MD
#   prevail/VB
#   ./.
#   Thank/NNP
#   you/PRP
#   ./.
#   May/NNP
#   God/NNP
#   continue/VBP
#   to/TO
#   bless/VB
#   (GPE America/NNP)
#   ./.)

# %%
#Step 4: Extract most common words

from collections import Counter

# Extract the most common words
word_counts = Counter(words)
top_words = word_counts.most_common(30)
print(top_words)
# Out:
# [('.', 60), (',', 59), ('the', 47), ('and', 42), ('of', 39), ('to', 26), ('a', 23), ('will', 18), ('our', 15), ('in', 14), ('is', 14), ('we', 12), ('military', 10), ('are', 10), ('have', 10), ('We', 9), ('by', 8), ('America', 8), ('I', 7), ('their', 6), ('who', 6), ('that', 6), ('not', 6), ('every', 6), ('Afghanistan', 5), ('this', 5), ('The', 5), ('you', 5), ('from', 5), ('my', 4)]

# %%
#Step 5: Analyze sentiment

from nltk.sentiment import SentimentIntensityAnalyzer

# Analyze sentiment
sia = SentimentIntensityAnalyzer()
sentiment = sia.polarity_scores(speech)
print(sentiment)
# Out:
# {'neg': 0.133, 'neu': 0.683, 'pos': 0.184, 'compound': 0.9966}

# %%
#Step 6: Extract keywords

from nltk.corpus import stopwords
from string import punctuation

# Extract keywords
stop_words = set(stopwords.words('english') + list(punctuation))
keywords = [word for word in words if word.lower() not in stop_words]
#print(keywords)

#word_countss = Counter(keywords)
#top_words = word_countss.most_common(30)

# %%
#Step 7: Display results

print(f'Top 10 words: {top_words}')
print(f'Sentiment analysis: {sentiment}')
print(f'Keywords: {keywords}')
# Out:
# Top 10 words: [('military', 10), ('America', 8), ('every', 6), ('Afghanistan', 5), ('Taliban', 4), ('today', 4), ('patience', 4), ('United', 3), ('States', 3), ('terrorist', 3), ('camps', 3), ('joined', 3), ('operation', 3), ('intelligence', 3), ('world', 3), ('clear', 3), ('make', 3), ('new', 3), ('terrorists', 3), ('also', 3), ('people', 3), ('battle', 3), ('peace', 3), ("'s", 3), ('ask', 3), ('freedom', 3), ('many', 3), ('around', 3), ('lot', 3), ("''", 3)]
# Sentiment analysis: {'neg': 0.133, 'neu': 0.683, 'pos': 0.184, 'compound': 0.9966}
# Keywords: ['orders', 'United', 'States', 'military', 'begun', 'strikes', 'al-Qaida', 'terrorist', 'training', 'camps', 'military', 'installations', 'Taliban', 'regime', 'Afghanistan', 'carefully', 'targeted', 'actions', 'designed', 'disrupt', 'use', 'Afghanistan', 'terrorist', 'base', 'operations', 'attack', 'military', 'capability', 'Taliban', 'regime', 'joined', 'operation', 'staunch', 'friend', 'Great', 'Britain', 'close', 'friends', 'including', 'Canada', 'Australia', 'Germany', 'France', 'pledged', 'forces', 'operation', 'unfolds', '40', 'countries', 'Middle', 'East', 'Africa', 'Europe', 'across', 'Asia', 'granted', 'air', 'transit', 'landing', 'rights', 'Many', 'shared', 'intelligence', 'supported', 'collective', 'world', 'two', 'weeks', 'ago', 'gave', 'Taliban', 'leaders', 'series', 'clear', 'specific', 'demands', 'Close', 'terrorist', 'training', 'camps', 'Hand', 'leaders', 'al-Qaida', 'network', 'return', 'foreign', 'nationals', 'including', 'American', 'citizens', 'unjustly', 'detained', 'country', 'None', 'demands', 'met', 'Taliban', 'pay', 'price', 'destroying', 'camps', 'disrupting', 'communications', 'make', 'difficult', 'terror', 'network', 'train', 'new', 'recruits', 'coordinate', 'evil', 'plans', 'Initially', 'terrorists', 'may', 'burrow', 'deeper', 'caves', 'entrenched', 'hiding', 'places', 'military', 'action', 'also', 'designed', 'clear', 'way', 'sustained', 'comprehensive', 'relentless', 'operations', 'drive', 'bring', 'justice', 'time', 'oppressed', 'people', 'Afghanistan', 'know', 'generosity', 'America', 'allies', 'strike', 'military', 'targets', 'also', 'drop', 'food', 'medicine', 'supplies', 'starving', 'suffering', 'men', 'women', 'children', 'Afghanistan', 'United', 'States', 'America', 'friend', 'Afghan', 'people', 'friends', 'almost', 'billion', 'worldwide', 'practice', 'Islamic', 'faith', 'United', 'States', 'America', 'enemy', 'aid', 'terrorists', 'barbaric', 'criminals', 'profane', 'great', 'religion', 'committing', 'murder', 'name', 'military', 'action', 'part', 'campaign', 'terrorism', 'another', 'front', 'war', 'already', 'joined', 'diplomacy', 'intelligence', 'freezing', 'financial', 'assets', 'arrests', 'known', 'terrorists', 'law', 'enforcement', 'agents', '38', 'countries', 'Given', 'nature', 'reach', 'enemies', 'win', 'conflict', 'patient', 'accumulation', 'successes', 'meeting', 'series', 'challenges', 'determination', 'purpose', 'Today', 'focus', 'Afghanistan', 'battle', 'broader', 'Every', 'nation', 'choice', 'make', 'conflict', 'neutral', 'ground', 'government', 'sponsors', 'outlaws', 'killers', 'innocents', 'become', 'outlaws', 'murderers', 'take', 'lonely', 'path', 'peril', "'m", 'speaking', 'today', 'Treaty', 'Room', 'White', 'House', 'place', 'American', 'presidents', 'worked', 'peace', "'re", 'peaceful', 'nation', 'Yet', 'learned', 'suddenly', 'tragically', 'peace', 'world', 'sudden', 'terror', 'face', 'today', "'s", 'new', 'threat', 'way', 'pursue', 'peace', 'pursue', 'threaten', 'ask', 'mission', 'fulfill', 'name', 'today', "'s", 'military', 'operation', 'Enduring', 'Freedom', 'defend', 'precious', 'freedoms', 'also', 'freedom', 'people', 'everywhere', 'live', 'raise', 'children', 'free', 'fear', 'know', 'many', 'Americans', 'feel', 'fear', 'today', 'government', 'taking', 'strong', 'precautions', 'law', 'enforcement', 'intelligence', 'agencies', 'working', 'aggressively', 'around', 'America', 'around', 'world', 'around', 'clock', 'request', 'many', 'governors', 'activated', 'National', 'Guard', 'strengthen', 'airport', 'security', 'called', 'reserves', 'reinforce', 'military', 'capability', 'strengthen', 'protection', 'homeland', 'months', 'ahead', 'patience', 'one', 'strengths', 'patience', 'long', 'waits', 'result', 'tighter', 'security', 'patience', 'understanding', 'take', 'time', 'achieve', 'goals', 'patience', 'sacrifices', 'may', 'come', 'Today', 'sacrifices', 'made', 'members', 'armed', 'forces', 'defend', 'us', 'far', 'home', 'proud', 'worried', 'families', 'command ...
